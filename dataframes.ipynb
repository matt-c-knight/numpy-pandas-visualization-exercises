# %%
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
from pydataset import data

# %%
df['passing_english'] = df.reading > 69

# %%
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67            False
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81             True
# 7     Marie    93       63       90             True
# 8    Albert    92       62       87             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72             True

# %%
df.sort_values(by='passing_english')
# Out:
#        name  math  english  reading  passing_english
# 1      Jane    88       79       67            False
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81             True
# 7     Marie    93       63       90             True
# 8    Albert    92       62       87             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72             True

# %% [markdown]
# Sort the english grades first by passing_english and then by student name.
# All the students that are failing english should be first, and within the
# students that are failing english they should be ordered alphabetically.
# The same should be true for the students passing english.
# (Hint: you can pass a list to the .sort_values method)

# %%
df.sort_values(['passing_english','name'], ascending=[True, True])
# Out:
#        name  math  english  reading  passing_english
# 1      Jane    88       79       67            False
# 4       Ada    77       92       98             True
# 11     Alan    92       62       72             True
# 8    Albert    92       62       87             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 5      John    79       76       93             True
# 7     Marie    93       63       90             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True
# 6    Thomas    82       64       81             True

# %% [markdown]
# Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

# %%
df.sort_values(['passing_english','english'], ascending=[True,False])
# Out:
#        name  math  english  reading  passing_english
# 1      Jane    88       79       67            False
# 10    Isaac    92       99       93             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 0     Sally    62       85       80             True
# 9   Richard    69       80       94             True
# 5      John    79       76       93             True
# 2     Suzie    94       74       95             True
# 6    Thomas    82       64       81             True
# 7     Marie    93       63       90             True
# 8    Albert    92       62       87             True
# 11     Alan    92       62       72             True

# %% [markdown]
# Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
df['overall_grade'] = ((df.math + df.english + df.reading) / 3).astype(int)

# %%
df
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    62       85       80             True             75
# 1      Jane    88       79       67            False             78
# 2     Suzie    94       74       95             True             87
# 3     Billy    98       96       88             True             94
# 4       Ada    77       92       98             True             89
# 5      John    79       76       93             True             82
# 6    Thomas    82       64       81             True             75
# 7     Marie    93       63       90             True             82
# 8    Albert    92       62       87             True             80
# 9   Richard    69       80       94             True             81
# 10    Isaac    92       99       93             True             94
# 11     Alan    92       62       72             True             75

# %%
mpg = data('mpg')

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %% [markdown]
# How many rows and columns are there?
#
# What are the data types of each column?

# %% [markdown]
# -234 rows and 11 columns
# -object,object,float,int,int,object,object,int,int,object,object

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# Rename the cty column to city.

# %%
mpg.rename(columns={'cty': 'city'})
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class  mileage_differnce  mileage_difference  average_mileage
# ...

# %% [markdown]
# Rename the hwy column to highway.

# %%
mpg.rename(columns={'hwy': 'highway'})
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %% [markdown]
# Do any cars have better city mileage than highway mileage?

# %%
mpg[mpg.city > mpg.hwy]
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, city, hwy, fl, class, mileage_differnce, mileage_difference, average_mileage]
# Index: []

# %% [markdown]
# Create a column named mileage_difference this column
# should contain the difference between highway and city mileage for each
# car.

# %%
mpg['mileage_difference'] = mpg.hwy - mpg.cty

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_differnce  mileage_difference
# ...

# %% [markdown]
# Which car (or cars) has the highest mileage difference?

# %%
highest = mpg.mileage_difference.max()

# %%
mpg[mpg.mileage_difference == highest]
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  cty  hwy fl  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f   24   36  c
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f   29   41  d
#
#           class  mileage_differnce  mileage_difference
# 107  subcompact                 12                  12
# 223  subcompact                 12                  12

# %% [markdown]
# Which compact class car has the lowest highway mileage? The best?

# %%
compact = mpg[mpg['class'] == 'compact']

# %%
compact.hwy.min()
# Out:
# 23

# %% [markdown]
# Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.cty + mpg.hwy) / 2

# %% [markdown]
# Which dodge car has the best average mileage? The worst?

# %%
mpg.average_mileage.max()
mpg[mpg.average_mileage == 39.5]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 222   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
#
#           class  mileage_differnce  mileage_difference  average_mileage
# 222  subcompact                  9                   9             39.5

# %% [markdown]
# mpg.average_mileage.min()

# %% [markdown]
# Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:

# %%
mpg.average_mileage.min()

# %%
mpg[mpg.average_mileage == 10.5]
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 55         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 60         dodge          durango 4wd    4.7  2008    8    auto(l5)   4    9
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 127         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4    9
#
#      hwy fl   class  mileage_differnce  mileage_difference  average_mileage
# 55    12  e  pickup                  3                   3             10.5
# 60    12  e     suv                  3                   3             10.5
# 66    12  e  pickup                  3                   3             10.5
# 70    12  e  pickup                  3                   3             10.5
# 127   12  e     suv                  3                   3             10.5

# %%
mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62 entries, Arctic fox to Red fox
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   body    62 non-null     float64
#  1   brain   62 non-null     float64
# dtypes: float64(2)
# memory usage: 1.5+ KB

# %%
mammals = data('Mammals')

# %%
mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %% [markdown]
# How many rows and columns are there?
# 4 and 107
# What are the data types of each column?
# float, float, bool, bool

# %% [markdown]
# What is the the weight of the fastest animal?

# %%
 mammals.speed.max()

# %%
mammals[mammals['speed'] == 110.0]
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %% [markdown]
# What is the overal percentage of specials?

# %%
sum(mammals['specials'] == True) / len(mammals)
# Out:
# 0.09345794392523364

# %% [markdown]
# How many animals are hoppers that are above the median speed? What percentage is this?

# %%
mammals['median_speed'] = sum(mammals['speed']) / len(mammals)

# %%
mammals
# Out:
#        weight  speed  hoppers  specials  median_speed
# 1    6000.000   35.0    False     False     46.208411
# 2    4000.000   26.0    False     False     46.208411
# 3    3000.000   25.0    False     False     46.208411
# 4    1400.000   45.0    False     False     46.208411
# 5     400.000   70.0    False     False     46.208411
# 6     350.000   70.0    False     False     46.208411
# 7     300.000   64.0    False     False     46.208411
# 8     260.000   70.0    False     False     46.208411
# 9     250.000   40.0    False     False     46.208411
# 10   3800.000   25.0    False      True     46.208411
# 11   1000.000   60.0    False     False     46.208411
# 12    900.000   70.0    False     False     46.208411
# 13    900.000   56.0    False     False     46.208411
# 14    800.000   29.0    False     False     46.208411
# 15    750.000   57.0    False     False     46.208411
# 16    500.000   32.0    False     False     46.208411
# ...

# %%
greater = sum(mammals['speed'] > mammals['median_speed'])

# %%
greater
# Out:
# 57

# %%
greater / len(mammals)
# Out:
# 0.5327102803738317
